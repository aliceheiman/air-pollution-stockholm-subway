# %%
# data-sorter.py: Sorts data into directories

import os
import pandas as pd
from shutil import copyfile

# %%
### By Date

# HELPER FUNCTIONS
def get_dataframe(sensor, filename):
    return pd.read_csv(f'./input/Sensor {sensor}/{filename}', skiprows=1, usecols=['Date', 'Time'])

def get_time_label(timestamp):
    timestamp = (timestamp + 20000)
        
    if 0 < timestamp < (120000):
        return 'AM' # before lunch
    if 120000 <= timestamp < 240000:
        return 'PM' # after lunch
    
def get_date_label(date):
    date = str(date)
    
    return date[:4] + '-' + date[4:6] + '-' + date[6:]

def get_duplicates(folder, base_name):
    """ returns the number of files that start with base_name"""
    
    # Get files in directory
    files = os.listdir(folder)
    
    # Get all files that starts with base_name
    base_files = [f for f in files if f.startswith(base_name)]
    
    # Return only length
    return len(base_files)

# Sensors in input to go through
#sensors = ['A', 'B', 'C', 'D', 'E']
sensors = ['1', '2', '3', '4', '5', '6']

# Go through every sensor
for current_sensor in sensors:
    print(f'Extracting data from Sensor {current_sensor}...')

    # Get all data files from sensor
    filenames = os.listdir(f'./input/Sensor {current_sensor}')
    filenames = sorted(filenames)

    for filename in filenames:
        src_path = f'./input/Sensor {current_sensor}/{filename}'

        # Load dataframe
        df = get_dataframe(current_sensor, filename)
        
        if len(df) == 0: continue
        
        # Extract date
        date = df['Date'][0]
        date_label = get_date_label(date)

        # Check date is not zero
        if date_label == '0--': continue

        # Extract time
        timestamp = df['Time'][0]
        time_label = get_time_label(timestamp)

        # Create new folder if not exists
        folder_path = f'./by-date/{date_label}'

        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Label the file (format: A-Morning)
        new_filename = f'{current_sensor}-{time_label}'

        # Check for duplicate file names
        duplicates = get_duplicates(folder_path, new_filename)

        if duplicates > 0:
            # Append number to end
            new_filename += str(duplicates + 1)

        new_filename += '.csv'

        # Copy file from input to sorted file structure
        dst_path = folder_path + '/' + new_filename
        
        # UNCOMMENT TO COPY FILES
        copyfile(src_path, dst_path)
        print(f'\tCopied {src_path} --> {dst_path}')

os.listdir('./by-date')
os.listdir('./by-date/2021-10-12')
# Out:
# Extracting data from Sensor 1...
# 	Copied ./input/Sensor 1/B1F0008.CSV --> ./by-date/2021-09-03/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0009.CSV --> ./by-date/2021-09-04/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0010.CSV --> ./by-date/2021-09-06/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0011.CSV --> ./by-date/2021-09-07/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0012.CSV --> ./by-date/2021-09-07/1-AM2.csv
# 	Copied ./input/Sensor 1/B1F0013.CSV --> ./by-date/2021-09-07/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0014.CSV --> ./by-date/2021-09-07/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0015.CSV --> ./by-date/2021-09-07/1-PM3.csv
# 	Copied ./input/Sensor 1/B1F0016.CSV --> ./by-date/2021-09-08/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0017.CSV --> ./by-date/2021-09-08/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0018.CSV --> ./by-date/2021-09-09/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0019.CSV --> ./by-date/2021-09-09/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0020.CSV --> ./by-date/2021-09-09/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0021.CSV --> ./by-date/2021-09-19/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0022.CSV --> ./by-date/2021-09-20/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0023.CSV --> ./by-date/2021-09-20/1-AM2.csv
# 	Copied ./input/Sensor 1/B1F0024.CSV --> ./by-date/2021-09-21/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0026.CSV --> ./by-date/2021-09-21/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0027.CSV --> ./by-date/2021-09-21/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0028.CSV --> ./by-date/2021-09-22/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0029.CSV --> ./by-date/2021-09-22/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0030.CSV --> ./by-date/2021-09-22/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0031.CSV --> ./by-date/2021-09-23/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0032.CSV --> ./by-date/2021-09-23/1-AM2.csv
# 	Copied ./input/Sensor 1/B1F0033.CSV --> ./by-date/2021-09-23/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0034.CSV --> ./by-date/2021-09-23/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0035.CSV --> ./by-date/2021-09-27/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0036.CSV --> ./by-date/2021-09-27/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0037.CSV --> ./by-date/2021-09-28/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0038.CSV --> ./by-date/2021-09-28/1-AM2.csv
# 	Copied ./input/Sensor 1/B1F0039.CSV --> ./by-date/2021-09-28/1-AM3.csv
# 	Copied ./input/Sensor 1/B1F0040.CSV --> ./by-date/2021-10-02/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0041.CSV --> ./by-date/2021-10-02/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0042.CSV --> ./by-date/2021-10-02/1-PM3.csv
# 	Copied ./input/Sensor 1/B1F0044.CSV --> ./by-date/2021-10-04/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0045.CSV --> ./by-date/2021-10-04/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0046.CSV --> ./by-date/2021-10-05/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0047.CSV --> ./by-date/2021-10-05/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0048.CSV --> ./by-date/2021-10-06/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0049.CSV --> ./by-date/2021-10-06/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0050.CSV --> ./by-date/2021-10-07/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0051.CSV --> ./by-date/2021-10-07/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0052.CSV --> ./by-date/2021-10-07/1-PM2.csv
# 	Copied ./input/Sensor 1/B1F0053.CSV --> ./by-date/2021-10-08/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0054.CSV --> ./by-date/2021-10-08/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0055.CSV --> ./by-date/2021-10-11/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0056.CSV --> ./by-date/2021-10-11/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0057.CSV --> ./by-date/2021-10-12/1-AM.csv
# 	Copied ./input/Sensor 1/B1F0058.CSV --> ./by-date/2021-10-12/1-PM.csv
# 	Copied ./input/Sensor 1/B1F0059.CSV --> ./by-date/2021-10-13/1-AM.csv
# Extracting data from Sensor 2...
# 	Copied ./input/Sensor 2/5A10005.CSV --> ./by-date/2021-08-18/2-AM.csv
# 	Copied ./input/Sensor 2/5A10006.CSV --> ./by-date/2021-08-18/2-PM.csv
# 	Copied ./input/Sensor 2/5A10007.CSV --> ./by-date/2021-09-03/2-AM.csv
# 	Copied ./input/Sensor 2/5A10008.CSV --> ./by-date/2021-09-03/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10010.CSV --> ./by-date/2021-09-03/2-AM3.csv
# 	Copied ./input/Sensor 2/5A10011.CSV --> ./by-date/2021-09-03/2-PM.csv
# 	Copied ./input/Sensor 2/5A10012.CSV --> ./by-date/2021-09-03/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10013.CSV --> ./by-date/2021-09-03/2-PM3.csv
# 	Copied ./input/Sensor 2/5A10014.CSV --> ./by-date/2021-09-04/2-PM.csv
# 	Copied ./input/Sensor 2/5A10015.CSV --> ./by-date/2021-09-06/2-AM.csv
# 	Copied ./input/Sensor 2/5A10016.CSV --> ./by-date/2021-09-06/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10017.CSV --> ./by-date/2021-09-06/2-PM.csv
# 	Copied ./input/Sensor 2/5A10018.CSV --> ./by-date/2021-09-06/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10019.CSV --> ./by-date/2021-09-07/2-AM.csv
# 	Copied ./input/Sensor 2/5A10020.CSV --> ./by-date/2021-09-07/2-PM.csv
# 	Copied ./input/Sensor 2/5A10021.CSV --> ./by-date/2021-09-07/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10022.CSV --> ./by-date/2021-09-08/2-AM.csv
# 	Copied ./input/Sensor 2/5A10023.CSV --> ./by-date/2021-09-08/2-PM.csv
# 	Copied ./input/Sensor 2/5A10024.CSV --> ./by-date/2021-09-10/2-AM.csv
# 	Copied ./input/Sensor 2/5A10025.CSV --> ./by-date/2021-09-10/2-PM.csv
# 	Copied ./input/Sensor 2/5A10026.CSV --> ./by-date/2021-09-10/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10027.CSV --> ./by-date/2021-09-12/2-PM.csv
# 	Copied ./input/Sensor 2/5A10028.CSV --> ./by-date/2021-09-19/2-PM.csv
# 	Copied ./input/Sensor 2/5A10029.CSV --> ./by-date/2021-09-20/2-AM.csv
# 	Copied ./input/Sensor 2/5A10030.CSV --> ./by-date/2021-09-20/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10031.CSV --> ./by-date/2021-09-22/2-PM.csv
# 	Copied ./input/Sensor 2/5A10032.CSV --> ./by-date/2021-09-22/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10033.CSV --> ./by-date/2021-09-23/2-AM.csv
# 	Copied ./input/Sensor 2/5A10034.CSV --> ./by-date/2021-09-23/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10035.CSV --> ./by-date/2021-09-23/2-AM3.csv
# 	Copied ./input/Sensor 2/5A10036.CSV --> ./by-date/2021-09-23/2-PM.csv
# 	Copied ./input/Sensor 2/5A10037.CSV --> ./by-date/2021-09-23/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10038.CSV --> ./by-date/2021-09-24/2-AM.csv
# 	Copied ./input/Sensor 2/5A10039.CSV --> ./by-date/2021-09-25/2-PM.csv
# 	Copied ./input/Sensor 2/5A10040.CSV --> ./by-date/2021-09-26/2-PM.csv
# 	Copied ./input/Sensor 2/5A10041.CSV --> ./by-date/2021-09-27/2-AM.csv
# 	Copied ./input/Sensor 2/5A10042.CSV --> ./by-date/2021-09-27/2-PM.csv
# 	Copied ./input/Sensor 2/5A10043.CSV --> ./by-date/2021-09-28/2-AM.csv
# 	Copied ./input/Sensor 2/5A10044.CSV --> ./by-date/2021-09-28/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10045.CSV --> ./by-date/2021-09-28/2-AM3.csv
# 	Copied ./input/Sensor 2/5A10046.CSV --> ./by-date/2021-09-29/2-AM.csv
# 	Copied ./input/Sensor 2/5A10047.CSV --> ./by-date/2021-09-29/2-PM.csv
# 	Copied ./input/Sensor 2/5A10048.CSV --> ./by-date/2021-09-30/2-AM.csv
# 	Copied ./input/Sensor 2/5A10050.CSV --> ./by-date/2021-09-30/2-PM.csv
# 	Copied ./input/Sensor 2/5A10051.CSV --> ./by-date/2021-09-30/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10052.CSV --> ./by-date/2021-10-01/2-AM.csv
# 	Copied ./input/Sensor 2/5A10053.CSV --> ./by-date/2021-10-01/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10054.CSV --> ./by-date/2021-10-01/2-PM.csv
# 	Copied ./input/Sensor 2/5A10055.CSV --> ./by-date/2021-10-01/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10056.CSV --> ./by-date/2021-10-01/2-PM3.csv
# 	Copied ./input/Sensor 2/5A10057.CSV --> ./by-date/2021-10-02/2-PM.csv
# 	Copied ./input/Sensor 2/5A10058.CSV --> ./by-date/2021-10-02/2-PM2.csv
# 	Copied ./input/Sensor 2/5A10059.CSV --> ./by-date/2021-10-02/2-PM3.csv
# 	Copied ./input/Sensor 2/5A10061.CSV --> ./by-date/2021-10-04/2-AM.csv
# 	Copied ./input/Sensor 2/5A10062.CSV --> ./by-date/2021-10-04/2-PM.csv
# 	Copied ./input/Sensor 2/5A10063.CSV --> ./by-date/2021-10-05/2-AM.csv
# 	Copied ./input/Sensor 2/5A10064.CSV --> ./by-date/2021-10-05/2-PM.csv
# 	Copied ./input/Sensor 2/5A10065.CSV --> ./by-date/2021-10-06/2-AM.csv
# 	Copied ./input/Sensor 2/5A10066.CSV --> ./by-date/2021-10-06/2-PM.csv
# 	Copied ./input/Sensor 2/5A10067.CSV --> ./by-date/2021-10-07/2-AM.csv
# 	Copied ./input/Sensor 2/5A10068.CSV --> ./by-date/2021-10-07/2-AM2.csv
# 	Copied ./input/Sensor 2/5A10069.CSV --> ./by-date/2021-10-07/2-PM.csv
# 	Copied ./input/Sensor 2/5A10070.CSV --> ./by-date/2021-10-08/2-AM.csv
# 	Copied ./input/Sensor 2/5A10071.CSV --> ./by-date/2021-10-08/2-PM.csv
# 	Copied ./input/Sensor 2/5A10072.CSV --> ./by-date/2021-10-11/2-AM.csv
# 	Copied ./input/Sensor 2/5A10073.CSV --> ./by-date/2021-10-11/2-PM.csv
# 	Copied ./input/Sensor 2/5A10074.CSV --> ./by-date/2021-10-12/2-AM.csv
# 	Copied ./input/Sensor 2/5A10075.CSV --> ./by-date/2021-10-12/2-PM.csv
# 	Copied ./input/Sensor 2/5A10076.CSV --> ./by-date/2021-10-13/2-AM.csv
# 	Copied ./input/Sensor 2/5A10077.CSV --> ./by-date/2021-10-13/2-PM.csv
# Extracting data from Sensor 3...
# 	Copied ./input/Sensor 3/2860001.CSV --> ./by-date/2021-08-21/3-PM.csv
# 	Copied ./input/Sensor 3/2860002.CSV --> ./by-date/2021-09-07/3-PM.csv
# 	Copied ./input/Sensor 3/2860003.CSV --> ./by-date/2021-09-07/3-PM2.csv
# 	Copied ./input/Sensor 3/2860004.CSV --> ./by-date/2021-09-07/3-PM3.csv
# 	Copied ./input/Sensor 3/2860005.CSV --> ./by-date/2021-09-09/3-AM.csv
# 	Copied ./input/Sensor 3/2860006.CSV --> ./by-date/2021-09-09/3-AM2.csv
# 	Copied ./input/Sensor 3/2860021.CSV --> ./by-date/2021-09-21/3-PM.csv
# 	Copied ./input/Sensor 3/2860022.CSV --> ./by-date/2021-09-22/3-PM.csv
# 	Copied ./input/Sensor 3/2860023.CSV --> ./by-date/2021-09-22/3-PM2.csv
# 	Copied ./input/Sensor 3/2860024.CSV --> ./by-date/2021-09-23/3-AM.csv
# 	Copied ./input/Sensor 3/2860025.CSV --> ./by-date/2021-09-23/3-AM2.csv
# 	Copied ./input/Sensor 3/2860026.CSV --> ./by-date/2021-09-23/3-PM.csv
# 	Copied ./input/Sensor 3/2860027.CSV --> ./by-date/2021-09-23/3-PM2.csv
# 	Copied ./input/Sensor 3/2860028.CSV --> ./by-date/2021-09-25/3-PM.csv
# 	Copied ./input/Sensor 3/2860029.CSV --> ./by-date/2021-09-26/3-PM.csv
# 	Copied ./input/Sensor 3/2860030.CSV --> ./by-date/2021-09-27/3-AM.csv
# 	Copied ./input/Sensor 3/2860033.CSV --> ./by-date/2021-10-01/3-AM.csv
# 	Copied ./input/Sensor 3/2860034.CSV --> ./by-date/2021-10-01/3-AM2.csv
# 	Copied ./input/Sensor 3/2860035.CSV --> ./by-date/2021-10-01/3-PM.csv
# 	Copied ./input/Sensor 3/2860036.CSV --> ./by-date/2021-10-01/3-PM2.csv
# 	Copied ./input/Sensor 3/2860037.CSV --> ./by-date/2021-10-02/3-PM.csv
# 	Copied ./input/Sensor 3/2860038.CSV --> ./by-date/2021-10-02/3-PM2.csv
# 	Copied ./input/Sensor 3/2860039.CSV --> ./by-date/2021-10-02/3-PM3.csv
# 	Copied ./input/Sensor 3/2860041.CSV --> ./by-date/2021-10-04/3-AM.csv
# 	Copied ./input/Sensor 3/2860042.CSV --> ./by-date/2021-10-04/3-PM.csv
# 	Copied ./input/Sensor 3/2860043.CSV --> ./by-date/2021-10-05/3-AM.csv
# 	Copied ./input/Sensor 3/2860044.CSV --> ./by-date/2021-10-05/3-PM.csv
# 	Copied ./input/Sensor 3/2860045.CSV --> ./by-date/2021-10-06/3-AM.csv
# 	Copied ./input/Sensor 3/2860046.CSV --> ./by-date/2021-10-06/3-PM.csv
# 	Copied ./input/Sensor 3/2860047.CSV --> ./by-date/2021-10-07/3-AM.csv
# 	Copied ./input/Sensor 3/2860048.CSV --> ./by-date/2021-10-07/3-AM2.csv
# 	Copied ./input/Sensor 3/2860049.CSV --> ./by-date/2021-10-07/3-PM.csv
# 	Copied ./input/Sensor 3/2860050.CSV --> ./by-date/2021-10-07/3-PM2.csv
# 	Copied ./input/Sensor 3/2860051.CSV --> ./by-date/2021-10-08/3-AM.csv
# 	Copied ./input/Sensor 3/2860052.CSV --> ./by-date/2021-10-08/3-PM.csv
# 	Copied ./input/Sensor 3/2860053.CSV --> ./by-date/2021-10-11/3-AM.csv
# 	Copied ./input/Sensor 3/2860054.CSV --> ./by-date/2021-10-11/3-PM.csv
# 	Copied ./input/Sensor 3/2860055.CSV --> ./by-date/2021-10-12/3-AM.csv
# 	Copied ./input/Sensor 3/2860056.CSV --> ./by-date/2021-10-12/3-PM.csv
# 	Copied ./input/Sensor 3/2860057.CSV --> ./by-date/2021-10-13/3-AM.csv
# Extracting data from Sensor 4...
# 	Copied ./input/Sensor 4/1ED0001.CSV --> ./by-date/2021-09-03/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0002.CSV --> ./by-date/2021-09-07/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0004.CSV --> ./by-date/2021-09-07/4-PM2.csv
# 	Copied ./input/Sensor 4/1ED0005.CSV --> ./by-date/2021-09-08/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0006.CSV --> ./by-date/2021-09-09/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0007.CSV --> ./by-date/2021-09-09/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0008.CSV --> ./by-date/2021-09-10/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0009.CSV --> ./by-date/2021-09-10/4-AM2.csv
# 	Copied ./input/Sensor 4/1ED0010.CSV --> ./by-date/2021-09-15/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0011.CSV --> ./by-date/2021-09-16/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0012.CSV --> ./by-date/2021-09-16/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0013.CSV --> ./by-date/2021-09-16/4-PM2.csv
# 	Copied ./input/Sensor 4/1ED0014.CSV --> ./by-date/2021-09-23/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0016.CSV --> ./by-date/2021-09-26/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0017.CSV --> ./by-date/2021-09-27/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0018.CSV --> ./by-date/2021-09-28/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0019.CSV --> ./by-date/2021-09-30/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0020.CSV --> ./by-date/2021-09-30/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0021.CSV --> ./by-date/2021-09-30/4-PM2.csv
# 	Copied ./input/Sensor 4/1ED0022.CSV --> ./by-date/2021-09-30/4-PM3.csv
# 	Copied ./input/Sensor 4/1ED0023.CSV --> ./by-date/2021-10-01/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0025.CSV --> ./by-date/2021-10-02/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0026.CSV --> ./by-date/2021-10-02/4-PM2.csv
# 	Copied ./input/Sensor 4/1ED0027.CSV --> ./by-date/2021-10-04/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0028.CSV --> ./by-date/2021-10-04/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0029.CSV --> ./by-date/2021-10-05/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0030.CSV --> ./by-date/2021-10-05/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0031.CSV --> ./by-date/2021-10-06/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0032.CSV --> ./by-date/2021-10-06/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0034.CSV --> ./by-date/2021-10-07/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0035.CSV --> ./by-date/2021-10-07/4-AM2.csv
# 	Copied ./input/Sensor 4/1ED0036.CSV --> ./by-date/2021-10-07/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0037.CSV --> ./by-date/2021-10-07/4-PM2.csv
# 	Copied ./input/Sensor 4/1ED0038.CSV --> ./by-date/2021-10-08/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0039.CSV --> ./by-date/2021-10-08/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0040.CSV --> ./by-date/2021-10-11/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0041.CSV --> ./by-date/2021-10-11/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0042.CSV --> ./by-date/2021-10-12/4-AM.csv
# 	Copied ./input/Sensor 4/1ED0043.CSV --> ./by-date/2021-10-12/4-PM.csv
# 	Copied ./input/Sensor 4/1ED0044.CSV --> ./by-date/2021-10-13/4-AM.csv
# Extracting data from Sensor 5...
# 	Copied ./input/Sensor 5/31A0004.CSV --> ./by-date/2021-10-04/5-PM.csv
# 	Copied ./input/Sensor 5/31A0005.CSV --> ./by-date/2021-10-05/5-AM.csv
# 	Copied ./input/Sensor 5/31A0006.CSV --> ./by-date/2021-10-05/5-PM.csv
# 	Copied ./input/Sensor 5/31A0007.CSV --> ./by-date/2021-10-06/5-AM.csv
# 	Copied ./input/Sensor 5/31A0008.CSV --> ./by-date/2021-10-06/5-PM.csv
# 	Copied ./input/Sensor 5/31A0009.CSV --> ./by-date/2021-10-07/5-AM.csv
# 	Copied ./input/Sensor 5/31A0010.CSV --> ./by-date/2021-10-07/5-AM2.csv
# 	Copied ./input/Sensor 5/31A0011.CSV --> ./by-date/2021-10-07/5-PM.csv
# 	Copied ./input/Sensor 5/31A0012.CSV --> ./by-date/2021-10-07/5-PM2.csv
# 	Copied ./input/Sensor 5/31A0013.CSV --> ./by-date/2021-10-08/5-AM.csv
# 	Copied ./input/Sensor 5/31A0014.CSV --> ./by-date/2021-10-08/5-PM.csv
# 	Copied ./input/Sensor 5/31A0015.CSV --> ./by-date/2021-10-11/5-AM.csv
# 	Copied ./input/Sensor 5/31A0016.CSV --> ./by-date/2021-10-11/5-PM.csv
# 	Copied ./input/Sensor 5/31A0017.CSV --> ./by-date/2021-10-12/5-AM.csv
# 	Copied ./input/Sensor 5/31A0018.CSV --> ./by-date/2021-10-12/5-PM.csv
# 	Copied ./input/Sensor 5/31A0019.CSV --> ./by-date/2021-10-13/5-AM.csv
# 	Copied ./input/Sensor 5/31A0020.CSV --> ./by-date/2021-10-13/5-PM.csv
# Extracting data from Sensor 6...
# 	Copied ./input/Sensor 6/2E40008.CSV --> ./by-date/2021-09-08/6-PM.csv
# 	Copied ./input/Sensor 6/2E40021.CSV --> ./by-date/2021-09-08/6-PM2.csv
# 	Copied ./input/Sensor 6/2E40033.CSV --> ./by-date/2021-10-02/6-PM.csv
# 	Copied ./input/Sensor 6/2E40035.CSV --> ./by-date/2021-10-04/6-AM.csv
# 	Copied ./input/Sensor 6/2E40036.CSV --> ./by-date/2021-10-04/6-PM.csv
# 	Copied ./input/Sensor 6/2E40040.CSV --> ./by-date/2021-10-05/6-AM.csv
# 	Copied ./input/Sensor 6/2E40071.CSV --> ./by-date/2021-10-06/6-AM.csv
# 	Copied ./input/Sensor 6/2E40072.CSV --> ./by-date/2021-10-06/6-PM.csv
# 	Copied ./input/Sensor 6/2E40073.CSV --> ./by-date/2021-10-07/6-AM.csv
# 	Copied ./input/Sensor 6/2E40075.CSV --> ./by-date/2021-10-07/6-AM2.csv
# 	Copied ./input/Sensor 6/2E40076.CSV --> ./by-date/2021-10-07/6-PM.csv
# 	Copied ./input/Sensor 6/2E40080.CSV --> ./by-date/2021-10-07/6-PM2.csv
# 	Copied ./input/Sensor 6/2E40085.CSV --> ./by-date/2021-10-07/6-PM3.csv
# 	Copied ./input/Sensor 6/2E40086.CSV --> ./by-date/2021-10-07/6-PM4.csv
# 	Copied ./input/Sensor 6/2E40087.CSV --> ./by-date/2021-10-07/6-PM5.csv
# 	Copied ./input/Sensor 6/2E40088.CSV --> ./by-date/2021-10-07/6-PM6.csv
# 	Copied ./input/Sensor 6/2E40089.CSV --> ./by-date/2021-10-07/6-PM7.csv
# 	Copied ./input/Sensor 6/2E40090.CSV --> ./by-date/2021-10-07/6-PM8.csv
# 	Copied ./input/Sensor 6/2E40091.CSV --> ./by-date/2021-10-07/6-PM9.csv
# 	Copied ./input/Sensor 6/2E40092.CSV --> ./by-date/2021-10-07/6-PM10.csv
# 	Copied ./input/Sensor 6/2E40093.CSV --> ./by-date/2021-10-07/6-PM11.csv
# 	Copied ./input/Sensor 6/2E40094.CSV --> ./by-date/2021-10-07/6-PM12.csv
# 	Copied ./input/Sensor 6/2E40095.CSV --> ./by-date/2021-10-07/6-PM13.csv
# 	Copied ./input/Sensor 6/2E40096.CSV --> ./by-date/2021-10-07/6-PM14.csv
# 	Copied ./input/Sensor 6/2E40097.CSV --> ./by-date/2021-10-07/6-PM15.csv
# 	Copied ./input/Sensor 6/2E40098.CSV --> ./by-date/2021-10-07/6-PM16.csv
# 	Copied ./input/Sensor 6/2E40099.CSV --> ./by-date/2021-10-07/6-PM17.csv
# 	Copied ./input/Sensor 6/2E40100.CSV --> ./by-date/2021-10-07/6-PM18.csv
# 	Copied ./input/Sensor 6/2E40101.CSV --> ./by-date/2021-10-07/6-PM19.csv
# 	Copied ./input/Sensor 6/2E40102.CSV --> ./by-date/2021-10-07/6-PM20.csv
# 	Copied ./input/Sensor 6/2E40103.CSV --> ./by-date/2021-10-07/6-PM21.csv
# 	Copied ./input/Sensor 6/2E40104.CSV --> ./by-date/2021-10-07/6-PM22.csv
# 	Copied ./input/Sensor 6/2E40105.CSV --> ./by-date/2021-10-07/6-PM23.csv
# 	Copied ./input/Sensor 6/2E40106.CSV --> ./by-date/2021-10-07/6-PM24.csv
# 	Copied ./input/Sensor 6/2E40107.CSV --> ./by-date/2021-10-07/6-PM25.csv
# 	Copied ./input/Sensor 6/2E40108.CSV --> ./by-date/2021-10-07/6-PM26.csv
# 	Copied ./input/Sensor 6/2E40109.CSV --> ./by-date/2021-10-07/6-PM27.csv
# 	Copied ./input/Sensor 6/2E40110.CSV --> ./by-date/2021-10-07/6-PM28.csv
# 	Copied ./input/Sensor 6/2E40111.CSV --> ./by-date/2021-10-07/6-PM29.csv
# 	Copied ./input/Sensor 6/2E40112.CSV --> ./by-date/2021-10-07/6-PM30.csv
# 	Copied ./input/Sensor 6/2E40113.CSV --> ./by-date/2021-10-07/6-PM31.csv
# 	Copied ./input/Sensor 6/2E40114.CSV --> ./by-date/2021-10-07/6-PM32.csv
# 	Copied ./input/Sensor 6/2E40115.CSV --> ./by-date/2021-10-07/6-PM33.csv
# 	Copied ./input/Sensor 6/2E40116.CSV --> ./by-date/2021-10-07/6-PM34.csv
# 	Copied ./input/Sensor 6/2E40117.CSV --> ./by-date/2021-10-07/6-PM35.csv
# 	Copied ./input/Sensor 6/2E40118.CSV --> ./by-date/2021-10-07/6-PM36.csv
# 	Copied ./input/Sensor 6/2E40119.CSV --> ./by-date/2021-10-07/6-PM37.csv
# 	Copied ./input/Sensor 6/2E40120.CSV --> ./by-date/2021-10-07/6-PM38.csv
# 	Copied ./input/Sensor 6/2E40121.CSV --> ./by-date/2021-10-07/6-PM39.csv
# 	Copied ./input/Sensor 6/2E40122.CSV --> ./by-date/2021-10-07/6-PM40.csv
# 	Copied ./input/Sensor 6/2E40123.CSV --> ./by-date/2021-10-07/6-PM41.csv
# 	Copied ./input/Sensor 6/2E40124.CSV --> ./by-date/2021-10-07/6-PM42.csv
# 	Copied ./input/Sensor 6/2E40125.CSV --> ./by-date/2021-10-07/6-PM43.csv
# 	Copied ./input/Sensor 6/2E40126.CSV --> ./by-date/2021-10-07/6-PM44.csv
# 	Copied ./input/Sensor 6/2E40127.CSV --> ./by-date/2021-10-07/6-PM45.csv
# 	Copied ./input/Sensor 6/2E40128.CSV --> ./by-date/2021-10-07/6-PM46.csv
# 	Copied ./input/Sensor 6/2E40129.CSV --> ./by-date/2021-10-07/6-PM47.csv
# 	Copied ./input/Sensor 6/2E40130.CSV --> ./by-date/2021-10-07/6-PM48.csv
# 	Copied ./input/Sensor 6/2E40131.CSV --> ./by-date/2021-10-08/6-AM.csv
# 	Copied ./input/Sensor 6/2E40132.CSV --> ./by-date/2021-10-08/6-AM2.csv
# 	Copied ./input/Sensor 6/2E40133.CSV --> ./by-date/2021-10-08/6-AM3.csv
# 	Copied ./input/Sensor 6/2E40134.CSV --> ./by-date/2021-10-08/6-AM4.csv
# 	Copied ./input/Sensor 6/2E40135.CSV --> ./by-date/2021-10-08/6-AM5.csv
# 	Copied ./input/Sensor 6/2E40136.CSV --> ./by-date/2021-10-08/6-AM6.csv
# 	Copied ./input/Sensor 6/2E40137.CSV --> ./by-date/2021-10-08/6-AM7.csv
# 	Copied ./input/Sensor 6/2E40138.CSV --> ./by-date/2021-10-11/6-AM.csv
# 	Copied ./input/Sensor 6/2E40139.CSV --> ./by-date/2021-10-11/6-PM.csv
# 	Copied ./input/Sensor 6/2E40140.CSV --> ./by-date/2021-10-12/6-AM.csv
# 	Copied ./input/Sensor 6/2E40141.CSV --> ./by-date/2021-10-12/6-PM.csv
# 	Copied ./input/Sensor 6/2E40142.CSV --> ./by-date/2021-10-13/6-AM.csv
# 	Copied ./input/Sensor 6/2E40143.CSV --> ./by-date/2021-10-13/6-AM2.csv
# 	Copied ./input/Sensor 6/2E40144.CSV --> ./by-date/2021-10-13/6-AM3.csv
# 	Copied ./input/Sensor 6/2E40145.CSV --> ./by-date/2021-10-13/6-AM4.csv
# 	Copied ./input/Sensor 6/2E40146.CSV --> ./by-date/2021-10-13/6-AM5.csv
# 	Copied ./input/Sensor 6/2E40147.CSV --> ./by-date/2021-10-13/6-AM6.csv
# 	Copied ./input/Sensor 6/2E40148.CSV --> ./by-date/2021-10-13/6-AM7.csv
# 	Copied ./input/Sensor 6/2E40149.CSV --> ./by-date/2021-10-13/6-AM8.csv
# 	Copied ./input/Sensor 6/2E40150.CSV --> ./by-date/2021-10-13/6-AM9.csv
# 	Copied ./input/Sensor 6/2E40151.CSV --> ./by-date/2021-10-13/6-AM10.csv
# 	Copied ./input/Sensor 6/2E40152.CSV --> ./by-date/2021-10-13/6-AM11.csv
# 	Copied ./input/Sensor 6/2E40153.CSV --> ./by-date/2021-10-13/6-AM12.csv
# 	Copied ./input/Sensor 6/2E40154.CSV --> ./by-date/2021-10-13/6-AM13.csv
# 	Copied ./input/Sensor 6/2E40155.CSV --> ./by-date/2021-10-13/6-AM14.csv
# 	Copied ./input/Sensor 6/2E40156.CSV --> ./by-date/2021-10-13/6-AM15.csv
# 	Copied ./input/Sensor 6/2E40157.CSV --> ./by-date/2021-10-13/6-AM16.csv
# 	Copied ./input/Sensor 6/2E40158.CSV --> ./by-date/2021-10-13/6-AM17.csv
# 	Copied ./input/Sensor 6/2E40159.CSV --> ./by-date/2021-10-13/6-AM18.csv
# 	Copied ./input/Sensor 6/2E40160.CSV --> ./by-date/2021-10-13/6-AM19.csv
# 	Copied ./input/Sensor 6/2E40161.CSV --> ./by-date/2021-10-13/6-AM20.csv
# 	Copied ./input/Sensor 6/2E40162.CSV --> ./by-date/2021-10-13/6-AM21.csv
# 	Copied ./input/Sensor 6/2E40163.CSV --> ./by-date/2021-10-13/6-AM22.csv
# 	Copied ./input/Sensor 6/2E40164.CSV --> ./by-date/2021-10-13/6-AM23.csv
# 	Copied ./input/Sensor 6/2E40165.CSV --> ./by-date/2021-10-13/6-AM24.csv
# 	Copied ./input/Sensor 6/2E40166.CSV --> ./by-date/2021-10-13/6-AM25.csv
# 	Copied ./input/Sensor 6/2E40167.CSV --> ./by-date/2021-10-13/6-AM26.csv
# 	Copied ./input/Sensor 6/2E40168.CSV --> ./by-date/2021-10-13/6-PM.csv
# 	Copied ./input/Sensor 6/2E40169.CSV --> ./by-date/2021-10-13/6-PM2.csv
# 	Copied ./input/Sensor 6/2E40170.CSV --> ./by-date/2021-10-13/6-PM3.csv
# 	Copied ./input/Sensor 6/2E40171.CSV --> ./by-date/2021-10-13/6-PM4.csv
# 	Copied ./input/Sensor 6/2E40172.CSV --> ./by-date/2021-10-13/6-PM5.csv
# 	Copied ./input/Sensor 6/2E40173.CSV --> ./by-date/2021-10-13/6-PM6.csv
# 	Copied ./input/Sensor 6/2E40174.CSV --> ./by-date/2021-10-13/6-PM7.csv
# 	Copied ./input/Sensor 6/2E40175.CSV --> ./by-date/2021-10-13/6-PM8.csv
# 	Copied ./input/Sensor 6/2E40176.CSV --> ./by-date/2021-10-13/6-PM9.csv
# 	Copied ./input/Sensor 6/2E40177.CSV --> ./by-date/2021-10-13/6-PM10.csv
# ['stations.txt',
#  '1-PM.csv',
#  'C-PM.csv',
#  'B-AM.csv',
#  'A-PM.csv',
#  '2-AM.csv',
#  '3-PM.csv',
#  'D-AM.csv',
#  'E-PM.csv',
#  '6-AM.csv',
#  '5-PM.csv',
#  '4-AM.csv',
#  'C-AM.csv',
#  'B-PM.csv',
#  '1-AM.csv',
#  '2-PM.csv',
#  '3-AM.csv',
#  'A-AM.csv',
#  '6-PM.csv',
#  'D-PM.csv',
#  'E-AM.csv',
#  '5-AM.csv',
#  '4-PM.csv']
